# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/ABHILASH/Downloads/loan_approved.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
len(df['Gender'].unique())
# Out:
# 3

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
len(df['Gender'])
# Out:
# 614

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Gender'], hue=df['Loan_Status (Approved)'])
plt.title("Gender vs Loan status")
plt.show()

# %%
df.loc[df['Gender'].isnull()==True,'Gender']='Male'

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
len(df['Married'].unique())
# Out:
# 3

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
len(df['Married'])
# Out:
# 614

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Married'], hue=df['Loan_Status (Approved)'])
plt.title("Married vs Loan status")
plt.show()

# %%
df.loc[df['Married'].isnull()==True,'Married']='Yes'

# %%
df['Married'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
df['Married'].isnull().sum()
# Out:
# np.int64(0)

# %%
len(df['Dependents'].unique())
# Out:
# 5

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
len(df['Dependents'])
# Out:
# 614

# %%
sns.countplot(x=df['Dependents'], hue=df['Loan_Status (Approved)'])
plt.title("Dependents vs Loan Approval Status")
plt.show()

# %%
df.loc[df['Dependents'].isnull()==True,'Dependents']='3+'

# %%
df['Dependents'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Dependents'].isnull().sum()
# Out:
# np.int64(0)

# %%
len(df['Dependents'].unique())
# Out:
# 4

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
len(df['Education'].unique())
# Out:
# 2

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
len(df['Education'])
# Out:
# 614

# %%
df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
len(df['Self_Employed'].unique())
# Out:
# 3

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
len(df['Self_Employed'])
# Out:
# 614

# %%
df.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Self_Employed'], hue=df['Loan_Status (Approved)'])
plt.title("Self_Employed vs Loan Approval Status")
plt.show()

# %%
df.loc[df['Self_Employed'].isnull()==True,'Self_Employed']='No'

# %%
df['Self_Employed'].isnull().sum()
# Out:
# np.int64(0)

# %%
len(df['LoanAmount'].unique())
# Out:
# 204

# %%
df['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
len(df['LoanAmount'])
# Out:
# 614

# %%
df.LoanAmount.value_counts()
# Out:
# LoanAmount
# 120.0    20
# 110.0    17
# 100.0    15
# 187.0    12
# 160.0    12
#          ..
# 292.0     1
# 142.0     1
# 350.0     1
# 496.0     1
# 253.0     1
# Name: count, Length: 203, dtype: int64

# %%
df.LoanAmount.hist()
plt.show()

# %%
import numpy as np
df.loc[df['LoanAmount'].isnull()==True,'LoanAmount']=np.median(df.LoanAmount.dropna(axis=0))

# %%
df['LoanAmount'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
len(df['Loan_Amount_Term'].unique())
# Out:
# 11

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
len(df['Loan_Amount_Term'])
# Out:
# 614

# %%
df.Loan_Amount_Term.value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df.LoanAmount.hist()
plt.show()

# %%
df.loc[df['Loan_Amount_Term'].isnull()==True,'Loan_Amount_Term']=np.median(df.Loan_Amount_Term.dropna(axis=0))

# %%
df['Loan_Amount_Term'].isnull().sum()
# Out:
# np.int64(0)

# %%
len(df['Credit_History'].unique())
# Out:
# 3

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
len(df['Credit_History'])
# Out:
# 614

# %%
df.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Credit_History'], hue=df['Loan_Status (Approved)'])
plt.title("Credit_History vs Loan Approval Status")
plt.show()

# %%
df.loc[df['Credit_History'].isnull()==True,'Credit_History']=1.0

# %%
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
print(df['ApplicantIncome'].skew())
# Out:
# 6.539513113994625

# %%
print(df['ApplicantIncome'].kurtosis())
# Out:
# 60.54067593369113

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df['Property_Area'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1=pd.get_dummies(df['Property_Area'],dtype=int,prefix='PA',drop_first=True)
df1
# Out:
#      PA_Semiurban  PA_Urban
# 0               0         1
# 1               0         0
# 2               0         1
# 3               0         1
# 4               0         1
# ..            ...       ...
# 609             0         0
# 610             0         0
# 611             0         1
# 612             0         1
# 613             1         0
#
# [614 rows x 2 columns]

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df=pd.concat([df,df1],axis=1).drop(['Property_Area'],axis=1)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
pd.get_dummies(df['Gender'],dtype=int,prefix='Gender',drop_first=True)
# Out:
#      Gender_Male
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 609            0
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %%
df1=pd.get_dummies(df['Gender'],dtype=int,prefix='Gender',drop_first=True)

# %%
df1
# Out:
#      Gender_Male
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 609            0
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Gender'],axis=1)
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df1=pd.get_dummies(df['Married'],dtype=int,prefix='Married',drop_first=True)

# %%
df1
# Out:
#      Married_Yes
# 0              0
# 1              1
# 2              1
# 3              1
# 4              0
# ..           ...
# 609            0
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Married'],axis=1)
df
# Out:
#       Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002          0      Graduate            No             5849
# 1    LP001003          1      Graduate            No             4583
# 2    LP001005          0      Graduate           Yes             3000
# 3    LP001006          0  Not Graduate            No             2583
# 4    LP001008          0      Graduate            No             6000
# ..        ...        ...           ...           ...              ...
# 609  LP002978          0      Graduate            No             2900
# 610  LP002979         3+      Graduate            No             4106
# 611  LP002983          1      Graduate            No             8072
# 612  LP002984          2      Graduate            No             7583
# 613  LP002990          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
df1=pd.get_dummies(df['Dependents'],dtype=int,prefix='Dependents',drop_first=True)
df1
# Out:
#      Dependents_1  Dependents_2  Dependents_3+
# 0               0             0              0
# 1               1             0              0
# 2               0             0              0
# 3               0             0              0
# 4               0             0              0
# ..            ...           ...            ...
# 609             0             0              0
# 610             0             0              1
# 611             1             0              0
# 612             0             1              0
# 613             0             0              0
#
# [614 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Dependents'],axis=1)
df
# Out:
#       Loan_ID     Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0    LP001002      Graduate            No             5849                0.0
# 1    LP001003      Graduate            No             4583             1508.0
# 2    LP001005      Graduate           Yes             3000                0.0
# 3    LP001006  Not Graduate            No             2583             2358.0
# 4    LP001008      Graduate            No             6000                0.0
# ..        ...           ...           ...              ...                ...
# 609  LP002978      Graduate            No             2900                0.0
# 610  LP002979      Graduate            No             4106                0.0
# 611  LP002983      Graduate            No             8072              240.0
# 612  LP002984      Graduate            No             7583                0.0
# 613  LP002990      Graduate           Yes             4583                0.0
#
# ...

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df1=pd.get_dummies(df['Education'],dtype=int,prefix='Education',drop_first=True)
df1
# Out:
#      Education_Not Graduate
# 0                         0
# 1                         0
# 2                         0
# 3                         1
# 4                         0
# ..                      ...
# 609                       0
# 610                       0
# 611                       0
# 612                       0
# 613                       0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Education'],axis=1)
df
# Out:
#       Loan_ID Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002            No             5849                0.0       128.0
# 1    LP001003            No             4583             1508.0       128.0
# 2    LP001005           Yes             3000                0.0        66.0
# 3    LP001006            No             2583             2358.0       120.0
# 4    LP001008            No             6000                0.0       141.0
# ..        ...           ...              ...                ...         ...
# 609  LP002978            No             2900                0.0        71.0
# 610  LP002979            No             4106                0.0        40.0
# 611  LP002983            No             8072              240.0       253.0
# 612  LP002984            No             7583                0.0       187.0
# 613  LP002990           Yes             4583                0.0       133.0
#
# ...

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df1=pd.get_dummies(df['Self_Employed'],dtype=int,prefix='Self_Employed',drop_first=True)
df1
# Out:
#      Self_Employed_Yes
# 0                    0
# 1                    0
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 609                  0
# 610                  0
# 611                  0
# 612                  0
# 613                  1
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Self_Employed'],axis=1)
df
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History Loan_Status (Approved)  PA_Semiurban  \
# 0               360.0             1.0                      Y             0
# ...

# %%
df['Credit_History'].unique()
# Out:
# array([1., 0.])

# %%
df1=pd.get_dummies(df['Credit_History'],dtype=int,prefix='Credit_History',drop_first=True)
df1
# Out:
#      Credit_History_1.0
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 609                   1
# 610                   1
# 611                   1
# 612                   1
# 613                   0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Credit_History'],axis=1)
df
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term Loan_Status (Approved)  PA_Semiurban  PA_Urban  \
# 0               360.0                      Y             0         1
# 1               360.0                      N             0         0
# ...

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')

# %%
la_trans=trans.fit_transform(df[['LoanAmount']])
la_trans.shape
# Out:
# (614, 1)

# %%
print("skewness: ",pd.Series(la_trans.reshape(614,)).skew())
print("kurtosis: ",pd.Series(la_trans.reshape(614,)).kurtosis())
# Out:
# skewness:  0.02083110923009167
# kurtosis:  2.4535382601295623
