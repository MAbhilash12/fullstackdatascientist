# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/ABHILASH/Downloads/loan_approved.csv")

# %%
print(df.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %% [markdown]
# loan_id--nominal---represents a unqiue identifier(represents catergory)
#
# Gender--nominal--describes the person is male or female(represents catergory)
#
# Married--nominal---describes the person is married or not (represents catergory)
#
# Dependents -- ordinal -- the no of dependents categorical because it represents the order/level of dependency
#
# education --nominal -- the person is graduated or not (represents catergory)
#
# self employed--nominal -- the person is self employed or not (represents catergory)
#
# applicant's income--continous--can be added
#
# co applicant's income--continous--can be added
#
# loan amount--continous--can be added
#
# loan amount term--discrete-counting of no of months or years
#
# credit history--nominal--category 1 or 0
#
# property area--nominal--category rural or urban
#
# loan status--nominal -- category y or n

# %%
len(df['Gender'].unique())
# Out:
# 3

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
len(df['Gender'])
# Out:
# 614

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
len(df['Dependents'].unique())
# Out:
# 5

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
len(df['Dependents'])
# Out:
# 614

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
len(df['ApplicantIncome'].unique())
# Out:
# 505

# %%
len(df['ApplicantIncome'])
# Out:
# 614

# %%
df['ApplicantIncome'].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %%
df.ApplicantIncome.value_counts()
# Out:
# ApplicantIncome
# 2500     9
# 4583     6
# 6000     6
# 2600     6
# 3750     5
#         ..
# 7660     1
# 5955     1
# 3365     1
# 2799     1
# 12841    1
# Name: count, Length: 505, dtype: int64

# %%
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64

# %%
df.ApplicantIncome.value_counts()
# Out:
# ApplicantIncome
# 2500     9
# 4583     6
# 6000     6
# 2600     6
# 3750     5
#         ..
# 7660     1
# 5955     1
# 3365     1
# 2799     1
# 12841    1
# Name: count, Length: 505, dtype: int64
